# %%
import sys
sys.path.append('./src/')
import numpy as np
import pickle
import torch
from global_var import *
from normalize import *
from data_load import *
from utils import *
from AE import AutoEncoder
from VAE import VAE
import KITree

torch.manual_seed(SEED)
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# load data
"""
available datasets and subsets: 
cicids_custom: [Tuesday, Wednesday, Thursday, Friday]
toniot_custom: [
    backdoor, ddos, dos,
    injection, mitm, password,
    runsomware, scanning, xss
]
cse_improved: [server1, server2]
"""

dataset = 'toniot_custom'
subset = 'dos'
X_train, X_eval, y_train, y_eval = load_data(dataset, subset, mode='train')
X_test, y_test = load_data(dataset, subset, mode='test')
with open(os.path.join(NORMALIZER_DIR, f'{dataset}_{subset}.norm'), 'rb') as f:
    normalizer = pickle.load(f)
X_train, X_eval = normalizer.transform(X_train), normalizer.transform(X_eval)
X_test = normalizer.transform(X_test)

# %%
# load black box model
"""
available trained models: AE, VAE, OCSVM, IForest
"""

blackbox = 'AE'
try:
    model = torch.load(os.path.join(TARGET_MODEL_DIR, f'{blackbox}_{dataset}_{subset}.model'), map_location=DEVICE).to(DEVICE)
    thres = model.thres
except:
    with open(os.path.join(TARGET_MODEL_DIR, f'{blackbox}_{dataset}_{subset}.model'), 'rb') as f:
        model = pickle.load(f)
    thres = -model.offset_

# %%
# test well-trained blackbox model
y_origin = model.predict(X_test)
# sklearn models have different prediction format
if blackbox == 'OCSVM' or blackbox == 'IForest':
    y_origin[y_origin == 1] = 0
    y_origin[y_origin == -1] = 1
evaluate_predictions(y_test, y_origin)
# Out:
# TPR:  1.0
# FPR:  0.018832391713747645
# TNR:  0.9811676082862524
# FNR:  0.0
# Accuracy: 0.9869366427171783
# Precision: 0.9591002044989775
# Recall: 1.0
# F1 Score: 0.9791231732776617

# %%
# prepare input of rule model
if blackbox == 'OCSVM' or blackbox == 'IForest':
    score = -model.score_samples(X_train)
    func = lambda x: -model.score_samples(x)
else:
    score = model.score_samples(X_train)
    func = lambda x: model.score_samples(x)

# %%
# extract rules from blackbox model using default hyperparameters
"""
here are some important hyperparameters you may try to calibrate:
max_levels = [5, 10, 15, 20, 25, 30]
n_beams = [2, 4, 6, 8, 10]
rhos = [0.01, 0.05, 0.1, 0.5, 1]
etas = [0.001, 0.005, 0.01, 0.05, 0.1, 0.5]
"""
rule_model = KITree.KITree(func, thres)
rule_model.fit(X_train, score)

# %%
# predict() returns 0 if normal else 1
y_pred = rule_model.predict(X_test)
X_perturb = perturb_data_point(X_test)
y_perturb = rule_model.predict(X_perturb)
evaluate_rule_model(y_test, y_pred, y_origin, y_perturb)
# Out:
# Accuracy: 0.977139124755062
# Precision: 0.9305555555555556
# Recall: 1.0
# F1 Score: 0.9640287769784173
# Fidelity: 0.9902024820378837
# robustness 1.0
# TPR:  1.0
# FPR:  0.03295668549905838
# TNR:  0.9670433145009416
# FNR:  0.0

# %%
"""
here are some useful functions:
get_depth(): get maximum depth of tree
get_leaf_num(): get leaf number of tree
"""
rule_model.get_depth(), rule_model.get_leaf_num()
# Out:
# (5, 21)

# %%
"""
get_rules_dict(feature name list, feature normalizer):
return a dict of rules where key is tree path to leaf and value is array of feature normality on this leaf;
[-inf, -inf] for all dimensions means always outputting abnormal on this leaf
"""
rule_model.get_rules_dict(CUSTOM_FEAT_COLS, normalizer)
# Out:
# {('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count <= 169.21179589013997',
#   'dim 1 feat fwd_count <= 79.5294102875443',
#   'dim 0 feat count <= 83.7232317671623'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count <= 169.21179589013997',
#   'dim 1 feat fwd_count <= 79.5294102875443',
#   'dim 0 feat count > 83.7232317671623'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count <= 169.21179589013997',
#   'dim 1 feat fwd_count > 79.5294102875443',
#   'dim 1 feat fwd_count <= 169.21179589013997'): array([[-2.45253349e+00, -2.18534428e-01],
#         [-2.14967442e+00,             inf],
#         [-2.19213531e+00,  4.56845534e-01],
#         [-1.38788203e+00,  4.69171712e-01],
#         [-3.87340313e+00,  2.91890310e-01],
#         [-1.44054607e-01,  3.80864097e-02],
#         [-2.62373801e+00,  7.99013750e-01],
#         [-1.07016858e+00,  8.35451571e-01],
#         [-1.08398772e+00,  1.05370442e+00],
#         [-1.17562319e-01,  1.99438237e-01],
#         [-1.13561793e+00,  8.15279805e-01],
#         [-9.30769064e-01,  1.19045391e+00],
#         [-1.15228162e+00,  1.16700740e+00],
#         [-1.65527822e-01,  2.14003879e-01],
#         [-9.10747594e-01,  1.38048590e+00],
#         [-1.81765148e-01,  3.54090587e-01],
#         [-6.58899927e-01,             inf],
#         [-1.10239872e-01,  1.60521641e-02],
#         [-2.54758689e-01, -2.07999190e-03],
#         [-3.26067301e-01,  9.13977976e-01],
#         [-4.74369877e-01,  9.22386642e-01],
#         [-1.41873845e-01,  2.68970576e-01],
#         [-3.78566140e-01,  3.62803871e-01],
#         [-4.28906254e-01,  4.26461754e-01],
#         [-8.07356851e-01, -6.91779613e-02],
#         [-9.79934531e-02,  6.18588929e-01],
#         [-3.68865688e-01,  5.25042350e-02],
#         [-7.37774589e+00,  2.67848018e-01],
#         [-1.65686824e-01,  1.18682760e-01],
#         [-1.06870663e-01,  1.54802350e-01]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count <= 169.21179589013997',
#   'dim 1 feat fwd_count > 79.5294102875443',
#   'dim 1 feat fwd_count > 169.21179589013997'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count > 169.21179589013997',
#   'dim 10 feat ps_fwd_var <= 90716.94039882961',
#   'dim 6 feat ps_var <= 108424.54931092782'): array([[-1.03625595,  2.34102054],
#         [       -inf,  2.59809175],
#         [-0.65691726,  2.68145882],
#         [-1.16930327,  0.68293275],
#         [-3.54997883,  0.53701104],
#         [-0.56821921,  0.38715222],
#         [-2.57593435,         inf],
#         [-1.01468113, -0.64510732],
#         [-1.14119137, -0.59170745],
#         [-0.41266667,  0.19957914],
#         [-1.51972157, -0.78876376],
#         [-0.6307577 ,  1.00247449],
#         [-0.59014926,  1.37006618],
#         [-0.96146281,  0.34412355],
#         [-1.16069186,  1.55038673],
#         [-0.39089622,  0.32332785],
#         [-0.74537167,         inf],
#         [-0.25281659,  0.0759755 ],
#         [-0.61703225,  0.20675551],
#         [-0.68681227,  0.39997843],
#         [-0.73188948,  0.67602714],
#         [-0.3142856 ,  0.42841824],
#         [-0.70580906,  0.25734524],
#         [-1.27363509,  1.17659075],
#         [-0.71852862,  0.32012824],
#         [-0.23621567,  0.45413228],
#         [-0.56031679,  0.21577862],
#         [-0.65454578,  0.76478911],
#         [-0.0589853 ,  0.35797057],
#         [-0.26720976,  0.45191956]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count > 169.21179589013997',
#   'dim 10 feat ps_fwd_var <= 90716.94039882961',
#   'dim 6 feat ps_var > 108424.54931092782'): array([[-1.43777952,  1.59096394],
#         [       -inf,  0.73211236],
#         [-1.22925579,  1.63877426],
#         [-0.86517571,  1.01274072],
#         [-0.87252493,  0.91176761],
#         [-0.65680278,  0.53996133],
#         [       -inf,  1.13067543],
#         [-1.64008282, -0.24013452],
#         [-1.87109142, -0.00731003],
#         [-0.92711576,  1.09240502],
#         [-1.61162572, -0.15216499],
#         [ 0.01270943,  1.66672949],
#         [ 0.26812232,  1.69177967],
#         [-1.02209218,  0.60176253],
#         [-0.10800517,  1.75917776],
#         [-1.62305308,  1.26290758],
#         [-0.7139279 ,         inf],
#         [-0.73700195,  1.32440621],
#         [-1.19494953,  0.77689866],
#         [-0.73931998,  1.13907066],
#         [-0.54150831,  1.40596993],
#         [-0.77136118,  0.60622729],
#         [-1.11408156,  1.36045578],
#         [-0.89145177,  0.51764919],
#         [-0.99135696,  0.51999481],
#         [-0.52408222,  1.00106543],
#         [-0.78861193,  0.45814449],
#         [-0.90677107,  1.28924053],
#         [-0.64111351,  0.82032278],
#         [-1.15142404,  0.50774374]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count > 169.21179589013997',
#   'dim 10 feat ps_fwd_var > 90716.94039882961',
#   'dim 24 feat iat_bwd_max <= 1.156072188887342'): array([[-1.02884994,  2.49054828],
#         [-0.71226297,  2.68524137],
#         [-1.55389028,  2.85136371],
#         [-1.01995659,  0.43824624],
#         [-0.2116582 ,  0.90115999],
#         [-0.46137096,  0.20232314],
#         [-1.06138667,  1.19646977],
#         [-0.27437823,  1.59694916],
#         [ 0.40028024,  1.55213222],
#         [-0.62888633,  0.59312323],
#         [ 0.16466206,  1.52520177],
#         [-1.50120827, -0.20287378],
#         [-1.22761862, -0.52128699],
#         [-0.69500813,  0.96735131],
#         [-1.07399594, -0.14825158],
#         [-0.71144438,  0.26341959],
#         [-0.97811838,         inf],
#         [-0.40096842,  0.49630281],
#         [-0.80225745,  0.48504116],
#         [-1.42665048,  0.67505522],
#         [-1.36128061,  0.49911146],
#         [-0.75007025,  0.71383229],
#         [-0.87317854,  0.28815044],
#         [-1.12028579,  0.62783958],
#         [-0.82451153,         inf],
#         [-0.37048666,  0.58802411],
#         [-0.50912409,  0.77644551],
#         [-0.66865403,  0.49769572],
#         [-0.25187044,  0.50940441],
#         [-0.49079058,  0.57687427]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max <= 0.9494180656981583',
#   'dim 1 feat fwd_count > 169.21179589013997',
#   'dim 10 feat ps_fwd_var > 90716.94039882961',
#   'dim 24 feat iat_bwd_max > 1.156072188887342'): array([[-1.07508588,  2.61976451],
#         [-0.27904034,  2.67441676],
#         [-1.26419092,  2.69903004],
#         [-0.74017673,  0.5200517 ],
#         [-0.33744258,  4.95011727],
#         [-0.45936715,  0.21656394],
#         [-0.79170798,  1.32523565],
#         [ 0.25795196,  1.58543568],
#         [ 0.43765852,  3.26999283],
#         [-0.16141588,  0.53679968],
#         [ 0.46198757,  1.42201991],
#         [-0.95863349, -0.51389843],
#         [-1.15525662, -0.53194918],
#         [-0.53908114,  0.42822632],
#         [-1.28194174, -0.4768961 ],
#         [-0.66950253,  0.61898093],
#         [-0.34759134,         inf],
#         [-0.3627518 ,  0.31476309],
#         [-0.65742953,  0.4129764 ],
#         [-0.6484105 ,  0.19135497],
#         [-0.62099145,  0.06263549],
#         [-0.33792398,  0.23371727],
#         [-0.32477779,  0.08542732],
#         [-0.93337399,  0.90882908],
#         [       -inf,  1.26710934],
#         [-0.42727242,  0.3128139 ],
#         [-0.22962695,  0.30122805],
#         [-0.55007089,  0.52258955],
#         [-0.20700868,  0.31979788],
#         [-0.30906889,  0.20025058]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max <= 2.0041699903074597',
#   'dim 1 feat fwd_count <= 124.37060308884213',
#   'dim 22 feat iat_fwd_var <= 0.1035344356125448'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max <= 2.0041699903074597',
#   'dim 1 feat fwd_count <= 124.37060308884213',
#   'dim 22 feat iat_fwd_var > 0.1035344356125448'): array([[-2.61226964, -1.82849291],
#         [-2.59514636,         inf],
#         [-2.4181228 , -1.30641484],
#         [ 0.01976283,  2.19251999],
#         [ 0.11961472,  0.34832838],
#         [-0.12499896,  0.04131015],
#         [ 0.28787891,  2.81245185],
#         [-1.01791584,  3.60563595],
#         [-1.09002434,  1.14100833],
#         [-0.11554195,  0.18073992],
#         [-1.09043604,  2.64164988],
#         [-1.02938454,  3.0143953 ],
#         [-1.18534721,  1.28261629],
#         [-0.20285038,  0.15692376],
#         [-0.95655746,  2.27405929],
#         [-0.09659475,  0.49213659],
#         [       -inf,  0.87259981],
#         [-0.12058702,  0.02683077],
#         [-0.1419332 ,  0.43283538],
#         [ 0.214274  ,  1.28849577],
#         [-0.18218604,  0.71419482],
#         [-0.1159511 ,  0.02733656],
#         [       -inf,  0.74369801],
#         [-0.1184235 ,  1.74737621],
#         [-0.27485593,  3.68035587],
#         [-0.12923996,  0.06726544],
#         [-0.30742994,  0.89472554],
#         [-4.99170578,  0.28408946],
#         [-0.08455813,  0.08086961],
#         [-0.06724559,  0.15795648]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max <= 2.0041699903074597',
#   'dim 1 feat fwd_count > 124.37060308884213',
#   'dim 10 feat ps_fwd_var <= 90716.94039882961'): array([[-2.45533868,  1.64914174],
#         [       -inf,  2.14905827],
#         [-2.49126636,  1.39546931],
#         [-1.24673419,  2.07253213],
#         [-3.08816265,  3.09752464],
#         [-0.2672829 ,  0.11386992],
#         [-2.57244566,  2.8760562 ],
#         [-1.0156066 , -0.77114171],
#         [-1.12810984, -0.74328308],
#         [-0.16905552,  0.1521482 ],
#         [-1.11438002, -0.84024259],
#         [-0.31692077,  3.04322949],
#         [-0.4642797 ,  2.35155747],
#         [-0.27753188,  0.12422497],
#         [-0.90523996,  2.33663297],
#         [-0.27825339,  0.52539733],
#         [       -inf,         inf],
#         [-0.13170221,  0.04075521],
#         [-0.17095545,  0.38114918],
#         [-0.45073897,  0.83102533],
#         [-0.28911742,  3.07657118],
#         [-0.21774677,  0.05961118],
#         [-0.37250319,  1.35379096],
#         [-0.54788072,  2.01615341],
#         [-0.25727022,  1.13972234],
#         [-0.13948774,  0.47298673],
#         [-0.33109723,  0.48010131],
#         [-0.35075598,  0.22862916],
#         [-0.10363519,  0.11199271],
#         [-0.05403153,  0.06510334]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max <= 2.0041699903074597',
#   'dim 1 feat fwd_count > 124.37060308884213',
#   'dim 10 feat ps_fwd_var > 90716.94039882961'): array([[-1.1287866 ,  1.7902022 ],
#         [-1.83903395,  1.63584625],
#         [-1.21673733,  1.85992922],
#         [-0.59957084,  0.63104483],
#         [ 0.15458097,  4.9238033 ],
#         [-0.09515724,  0.01193503],
#         [-0.57367656,  0.95511706],
#         [ 0.35882441,  2.42945847],
#         [ 0.32002958,  3.13464049],
#         [-0.17463057,  0.03216287],
#         [ 0.70856255,  2.17356805],
#         [-1.50143269, -0.55892117],
#         [-1.53040845, -0.76708168],
#         [-0.16402966,  0.12624835],
#         [-0.94975803, -0.54752937],
#         [-0.35911589,  0.24934551],
#         [       -inf,         inf],
#         [-0.16155922,  0.28829646],
#         [-0.19134685,  0.25871785],
#         [-0.43548457,  0.68493526],
#         [-0.53389371,  0.94480829],
#         [-0.18550038,  0.05051089],
#         [-0.43936064,  0.47173892],
#         [-0.9825972 ,  0.44754701],
#         [-0.12856542,  2.03060137],
#         [-0.09155167,  0.41283068],
#         [-0.18845099,  0.38033988],
#         [-1.06781519,  0.22335994],
#         [-0.54722306,  0.17932265],
#         [-0.15063928,  0.06844025]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max > 2.0041699903074597',
#   'dim 16 feat iat_max <= 3.058921914916761',
#   'dim 8 feat ps_fwd_max <= 787.453634894992'): array([[-2.73759783,  1.21481634],
#         [-2.74692547,  2.0096915 ],
#         [-2.47641252,  0.49508559],
#         [-0.80698008,  2.4839165 ],
#         [ 0.14844749,  0.32476912],
#         [-0.1067547 ,  0.05596477],
#         [-2.05705777,  3.35331067],
#         [-1.10875547, -0.72485363],
#         [-1.05332121, -0.58469298],
#         [-0.09368854,  0.16462212],
#         [-1.07703862, -0.82760834],
#         [ 0.03434022,  2.7959171 ],
#         [ 0.98596516,  1.1812259 ],
#         [-0.12441047,  0.02825526],
#         [-0.57482583,  2.81293191],
#         [-0.34424004,  0.61616541],
#         [       -inf,         inf],
#         [-0.11701829,  0.09062705],
#         [-0.23932039,  0.60308916],
#         [-0.51164498,  1.16537151],
#         [ 0.01978691,  8.20444399],
#         [-0.22805902,  0.23183985],
#         [-0.14486709,  5.41052086],
#         [-0.30933752,  1.63406558],
#         [ 0.60326395,  1.76135147],
#         [-0.10784558,  0.12540247],
#         [-0.19881264,  1.04806319],
#         [-0.65596669,  0.21986695],
#         [-0.10128856,  0.15173232],
#         [-0.18393195,  0.07883338]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max > 2.0041699903074597',
#   'dim 16 feat iat_max <= 3.058921914916761',
#   'dim 8 feat ps_fwd_max > 787.453634894992'): array([[-2.2627613 ,  1.03697796],
#         [-2.45452222,  0.54445756],
#         [-1.75109234,  1.47271522],
#         [-0.48390759,  2.12227171],
#         [ 0.10050538,  4.9390989 ],
#         [-0.14304206,  0.05403623],
#         [-0.25252306,  5.82132851],
#         [-0.92814576,  3.40884742],
#         [       -inf,  3.29700697],
#         [-0.12387019,  0.10046493],
#         [-1.0338634 ,  2.63356685],
#         [-0.96564058,  2.41009145],
#         [-1.10038908,  3.43447638],
#         [-0.15739163,  0.18563258],
#         [-0.9375714 ,  4.31350905],
#         [-0.18071258,  0.33905341],
#         [       -inf,         inf],
#         [-0.15161127,  0.02677202],
#         [-0.1730468 ,  0.50327281],
#         [-0.23131676,  1.15418845],
#         [ 0.49129479,  1.4186393 ],
#         [-0.16174733,  0.10572002],
#         [-0.23891447,  1.07224813],
#         [-0.62108388,  0.89979053],
#         [-0.07057635,  3.93607359],
#         [-0.11715882,  0.03214256],
#         [-0.19907392,  0.9885134 ],
#         [-0.63012536,  0.28666878],
#         [-0.06592717,  0.06565854],
#         [-0.09098894,  0.1236205 ]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max > 2.0041699903074597',
#   'dim 16 feat iat_max > 3.058921914916761',
#   'dim 16 feat iat_max <= 8.332681537963268'): array([[-2.91818722,  1.05466913],
#         [-2.42551215,  1.46875146],
#         [-2.65321543,  0.5948947 ],
#         [-0.56990962,  2.52409053],
#         [ 0.11233449,  4.98748207],
#         [-0.18338759,  0.04036767],
#         [-0.33268316,  4.21097141],
#         [-1.05855825,  2.4082323 ],
#         [-1.13912425,  3.15692454],
#         [-0.14523803,  0.12551279],
#         [-1.02284076,  4.0353325 ],
#         [-1.03174392,  3.42712341],
#         [-1.08409421,  3.35806305],
#         [-0.14272107,  0.01071751],
#         [-1.05270381,  3.07575888],
#         [-0.26638714,  0.57606216],
#         [       -inf,  6.042058  ],
#         [-0.10259168,  0.03343987],
#         [-0.03538872,  1.67171385],
#         [-0.55717175,  0.98164274],
#         [-0.3024725 ,  9.5616075 ],
#         [-0.16813147,  0.12000826],
#         [-0.09494781,  6.7221225 ],
#         [-0.46047577,  2.3977034 ],
#         [-0.2056858 ,  7.17661356],
#         [-0.15729459,  0.04346392],
#         [-0.25068575,  3.68363366],
#         [-2.32532913,  0.24561517],
#         [-0.09622381,  0.09172013],
#         [-0.08564869,  0.05906292]]),
#  ('dim 3 feat ps_mean <= 378.8089203433244',
#   'dim 16 feat iat_max > 0.9494180656981583',
#   'dim 16 feat iat_max > 2.0041699903074597',
#   'dim 16 feat iat_max > 3.058921914916761',
#   'dim 16 feat iat_max > 8.332681537963268'): array([[-2.98242972, -0.79879496],
#         [-3.26096642, -0.9779267 ],
#         [-2.39979122, -0.42947135],
#         [-0.84807223,  0.17605976],
#         [ 0.12908723,  0.36251984],
#         [-0.23329335,  0.0441867 ],
#         [-1.45499998,  0.08208526],
#         [-0.99673268, -0.85091576],
#         [-1.14931879, -0.73503074],
#         [-0.20472964,  0.12578316],
#         [-1.1257643 , -0.89161305],
#         [ 0.11810226,  0.71015188],
#         [ 1.03464046,  1.31340136],
#         [-0.14659978,  0.1262918 ],
#         [-0.27699943,  0.89405487],
#         [-0.043215  ,  0.40224416],
#         [ 7.52453266, 10.83440417],
#         [-0.09520384,  0.08436558],
#         [ 0.49830739,  2.65594814],
#         [ 0.1229937 ,  0.79901599],
#         [-0.34901298,  8.43356838],
#         [-0.10567657,  0.09540103],
#         [-0.20490177,  7.66249423],
#         [-0.05234743,  1.08736186],
#         [ 6.6544844 ,  9.88461473],
#         [-0.17542275,  0.17287732],
#         [ 0.64837159,  5.22242351],
#         [-4.25738597,  0.25963341],
#         [-0.05560013,  0.05534224],
#         [-0.14818243,  0.11413401]]),
#  ('dim 3 feat ps_mean > 378.8089203433244',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean > 378.8089203433244',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count > 34.68821748624646'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean > 378.8089203433244',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count > 34.68821748624646'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean > 378.8089203433244',
#   'dim 1 feat fwd_count <= 34.68821748624646',
#   'dim 1 feat fwd_count > 34.68821748624646'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]]),
#  ('dim 3 feat ps_mean > 378.8089203433244',
#   'dim 1 feat fwd_count > 34.68821748624646'): array([[-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf],
#         [-inf, -inf]])}

# %%
"""
predict_rule_out(data sample, feature normalizer, feature name list=None):
return two lists; first is rules of tree path to a leaf;
second is rules of feature normality on this leaf, where "satisfy" indicates if data sample satisfy this rule;
second list is empty if this leaf is always determined abnormal
"""
rule_model.predict_rule_out(X_test[100], normalizer, CUSTOM_FEAT_COLS)
# Out:
# ([{'feature_id': 3,
#    'feature_name': 'ps_mean',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 378.8089203433244},
#   {'feature_id': 16,
#    'feature_name': 'iat_max',
#    'comparison': '<=',
#    'value': 0.03418612480163574,
#    'threshold': 0.9494180656981583},
#   {'feature_id': 1,
#    'feature_name': 'fwd_count',
#    'comparison': '<=',
#    'value': 100.0,
#    'threshold': 169.21179589013997},
#   {'feature_id': 1,
#    'feature_name': 'fwd_count',
#    'comparison': '>',
#    'value': 100.0,
#    'threshold': 79.5294102875443}],
#  [{'feature_id': 0,
#    'feature_name': 'count',
#    'comparison': '<=',
#    'value': 100.0,
#    'threshold': 405.2808585327424,
#    'satisfy': True},
#   {'feature_id': 0,
#    'feature_name': 'count',
#    'comparison': '>',
#    'value': 100.0,
#    'threshold': 215.3123339338876,
#    'satisfy': False},
#   {'feature_id': 1,
#    'feature_name': 'fwd_count',
#    'comparison': '>',
#    'value': 100.0,
#    'threshold': 117.65902353189982,
#    'satisfy': False},
#   {'feature_id': 2,
#    'feature_name': 'bwd_count',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 232.08480219034558,
#    'satisfy': True},
#   {'feature_id': 2,
#    'feature_name': 'bwd_count',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 102.93192794061544,
#    'satisfy': False},
#   {'feature_id': 3,
#    'feature_name': 'ps_mean',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 217.49725166735828,
#    'satisfy': True},
#   {'feature_id': 3,
#    'feature_name': 'ps_mean',
#    'comparison': '>',
#    'value': 40.0,
#    'threshold': 99.13108670800464,
#    'satisfy': False},
#   {'feature_id': 4,
#    'feature_name': 'ps_max',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 1527.1252292173117,
#    'satisfy': True},
#   {'feature_id': 4,
#    'feature_name': 'ps_max',
#    'comparison': '>',
#    'value': 40.0,
#    'threshold': 232.0646523799603,
#    'satisfy': False},
#   {'feature_id': 5,
#    'feature_name': 'ps_min',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 56.1912269690612,
#    'satisfy': True},
#   {'feature_id': 5,
#    'feature_name': 'ps_min',
#    'comparison': '>',
#    'value': 40.0,
#    'threshold': 46.867889700731595,
#    'satisfy': False},
#   {'feature_id': 6,
#    'feature_name': 'ps_var',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 141241.73400258404,
#    'satisfy': True},
#   {'feature_id': 6,
#    'feature_name': 'ps_var',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 662.0797195626656,
#    'satisfy': False},
#   {'feature_id': 7,
#    'feature_name': 'ps_fwd_mean',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 276.43878420542774,
#    'satisfy': True},
#   {'feature_id': 7,
#    'feature_name': 'ps_fwd_mean',
#    'comparison': '>',
#    'value': 40.0,
#    'threshold': 41.156196695779215,
#    'satisfy': False},
#   {'feature_id': 8,
#    'feature_name': 'ps_fwd_max',
#    'comparison': '<=',
#    'value': 39.999999999999886,
#    'threshold': 1544.5921243281696,
#    'satisfy': True},
#   {'feature_id': 8,
#    'feature_name': 'ps_fwd_max',
#    'comparison': '>',
#    'value': 39.999999999999886,
#    'threshold': 8.555104171518337,
#    'satisfy': True},
#   {'feature_id': 9,
#    'feature_name': 'ps_fwd_min',
#    'comparison': '<=',
#    'value': 40.0,
#    'threshold': 61.07548081428,
#    'satisfy': True},
#   {'feature_id': 9,
#    'feature_name': 'ps_fwd_min',
#    'comparison': '>',
#    'value': 40.0,
#    'threshold': 49.124631522808556,
#    'satisfy': False},
#   {'feature_id': 10,
#    'feature_name': 'ps_fwd_var',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 168176.17519906134,
#    'satisfy': True},
#   {'feature_id': 10,
#    'feature_name': 'ps_fwd_var',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': -17177.4234260222,
#    'satisfy': True},
#   {'feature_id': 11,
#    'feature_name': 'ps_bwd_mean',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 380.1681687063853,
#    'satisfy': True},
#   {'feature_id': 11,
#    'feature_name': 'ps_bwd_mean',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 48.71900540100762,
#    'satisfy': False},
#   {'feature_id': 12,
#    'feature_name': 'ps_bwd_max',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 1553.1940628568075,
#    'satisfy': True},
#   {'feature_id': 12,
#    'feature_name': 'ps_bwd_max',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': -55.92788786279368,
#    'satisfy': True},
#   {'feature_id': 13,
#    'feature_name': 'ps_bwd_min',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 61.35611308334383,
#    'satisfy': True},
#   {'feature_id': 13,
#    'feature_name': 'ps_bwd_min',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 48.157768235712425,
#    'satisfy': False},
#   {'feature_id': 14,
#    'feature_name': 'ps_bwd_var',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 237322.51131485138,
#    'satisfy': True},
#   {'feature_id': 14,
#    'feature_name': 'ps_bwd_var',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': -8877.200245654807,
#    'satisfy': True},
#   {'feature_id': 15,
#    'feature_name': 'iat_mean',
#    'comparison': '<=',
#    'value': 0.0049671307958736866,
#    'threshold': 0.270864071448811,
#    'satisfy': True},
#   {'feature_id': 15,
#    'feature_name': 'iat_mean',
#    'comparison': '>',
#    'value': 0.0049671307958736866,
#    'threshold': 0.10247020905334003,
#    'satisfy': False},
#   {'feature_id': 16,
#    'feature_name': 'iat_max',
#    'comparison': '>',
#    'value': 0.03418612480163574,
#    'threshold': 0.2544421000478059,
#    'satisfy': False},
#   {'feature_id': 17,
#    'feature_name': 'iat_min',
#    'comparison': '<=',
#    'value': 1.9073486328125e-06,
#    'threshold': 0.013734084489427333,
#    'satisfy': True},
#   {'feature_id': 17,
#    'feature_name': 'iat_min',
#    'comparison': '>',
#    'value': 1.9073486328125e-06,
#    'threshold': -0.02014881974185749,
#    'satisfy': True},
#   {'feature_id': 18,
#    'feature_name': 'iat_var',
#    'comparison': '<=',
#    'value': 3.290461541176348e-05,
#    'threshold': 0.06497531367825145,
#    'satisfy': True},
#   {'feature_id': 18,
#    'feature_name': 'iat_var',
#    'comparison': '>',
#    'value': 3.290461541176348e-05,
#    'threshold': -0.033587256364270734,
#    'satisfy': True},
#   {'feature_id': 19,
#    'feature_name': 'iat_fwd_mean',
#    'comparison': '<=',
#    'value': 0.0049671307958736866,
#    'threshold': 0.538631684999276,
#    'satisfy': True},
#   {'feature_id': 19,
#    'feature_name': 'iat_fwd_mean',
#    'comparison': '>',
#    'value': 0.0049671307958736866,
#    'threshold': 0.2119743790966106,
#    'satisfy': False},
#   {'feature_id': 20,
#    'feature_name': 'iat_fwd_max',
#    'comparison': '<=',
#    'value': 0.03418612480163574,
#    'threshold': 2.480828195619519,
#    'satisfy': True},
#   {'feature_id': 20,
#    'feature_name': 'iat_fwd_max',
#    'comparison': '>',
#    'value': 0.03418612480163574,
#    'threshold': 0.5578521169177681,
#    'satisfy': False},
#   {'feature_id': 21,
#    'feature_name': 'iat_fwd_min',
#    'comparison': '<=',
#    'value': 1.9073486328125e-06,
#    'threshold': 0.06436953247197005,
#    'satisfy': True},
#   {'feature_id': 21,
#    'feature_name': 'iat_fwd_min',
#    'comparison': '>',
#    'value': 1.9073486328125e-06,
#    'threshold': -0.023822513747572247,
#    'satisfy': True},
#   {'feature_id': 22,
#    'feature_name': 'iat_fwd_var',
#    'comparison': '<=',
#    'value': 3.290461541176348e-05,
#    'threshold': 0.20933137548181008,
#    'satisfy': True},
#   {'feature_id': 22,
#    'feature_name': 'iat_fwd_var',
#    'comparison': '>',
#    'value': 3.290461541176348e-05,
#    'threshold': -0.006858926511994615,
#    'satisfy': True},
#   {'feature_id': 23,
#    'feature_name': 'iat_bwd_mean',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 0.3865773036903336,
#    'satisfy': True},
#   {'feature_id': 23,
#    'feature_name': 'iat_bwd_mean',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 0.22339778661025902,
#    'satisfy': False},
#   {'feature_id': 24,
#    'feature_name': 'iat_bwd_max',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 1.0776159530748877,
#    'satisfy': True},
#   {'feature_id': 24,
#    'feature_name': 'iat_bwd_max',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': 0.2404311619461904,
#    'satisfy': False},
#   {'feature_id': 25,
#    'feature_name': 'iat_bwd_min',
#    'comparison': '<=',
#    'value': -4.336808689942018e-19,
#    'threshold': 0.1028982609412471,
#    'satisfy': True},
#   {'feature_id': 25,
#    'feature_name': 'iat_bwd_min',
#    'comparison': '>',
#    'value': -4.336808689942018e-19,
#    'threshold': -0.01254145488813906,
#    'satisfy': True},
#   {'feature_id': 26,
#    'feature_name': 'iat_bwd_var',
#    'comparison': '<=',
#    'value': 0.0,
#    'threshold': 0.12794618701738075,
#    'satisfy': True},
#   {'feature_id': 26,
#    'feature_name': 'iat_bwd_var',
#    'comparison': '>',
#    'value': 0.0,
#    'threshold': -0.02995052821965684,
#    'satisfy': True},
#   {'feature_id': 27,
#    'feature_name': 'dur',
#    'comparison': '<=',
#    'value': 0.4917459487914968,
#    'threshold': 60.41161191473265,
#    'satisfy': True},
#   {'feature_id': 27,
#    'feature_name': 'dur',
#    'comparison': '>',
#    'value': 0.4917459487914968,
#    'threshold': 33.032596351512424,
#    'satisfy': False},
#   {'feature_id': 28,
#    'feature_name': 'l4_proto',
#    'comparison': '<=',
#    'value': 6.0,
#    'threshold': 6.118682760097652,
#    'satisfy': True},
#   {'feature_id': 28,
#    'feature_name': 'l4_proto',
#    'comparison': '>',
#    'value': 6.0,
#    'threshold': 5.8343131755069715,
#    'satisfy': True},
#   {'feature_id': 29,
#    'feature_name': 'service_port',
#    'comparison': '<=',
#    'value': 106.0,
#    'threshold': 1883.1548023503067,
#    'satisfy': True},
#   {'feature_id': 29,
#    'feature_name': 'service_port',
#    'comparison': '>',
#    'value': 106.0,
#    'threshold': 1882.8931293365913,
#    'satisfy': False}])
